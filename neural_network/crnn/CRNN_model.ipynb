# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
npzfile = np.load('shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Electronic
# D:\Anaconda\envs\tf1\lib\site-packages\librosa\display.py:797: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# D:\Anaconda\envs\tf1\lib\site-packages\librosa\display.py:797: MatplotlibDeprecationWarning: The 'linthreshy' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train, num_classes=num_classes)
y_valid = to_categorical(y_valid, num_classes=num_classes)

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# WARNING:tensorflow:From D:\Anaconda\envs\tf1\lib\site-packages\tensorflow\python\util\deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_1 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_2 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_3 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 133,520
# Trainable params: 133,184
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 6394 samples, validate on 800 samples
# Epoch 1/70
# 6394/6394 [==============================] - 28s 4ms/step - loss: 2.1356 - acc: 0.2842 - val_loss: 2.0773 - val_acc: 0.3137
#
# Epoch 00001: val_acc improved from -inf to 0.31375, saving model to ./models/crnn/weights.best.h5
# Epoch 2/70
# 6394/6394 [==============================] - 29s 4ms/step - loss: 1.9815 - acc: 0.3605 - val_loss: 2.3121 - val_acc: 0.2450
#
# Epoch 00002: val_acc did not improve from 0.31375
# Epoch 3/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.9112 - acc: 0.3800 - val_loss: 2.0763 - val_acc: 0.2462
#
# Epoch 00003: val_acc did not improve from 0.31375
# Epoch 4/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.8634 - acc: 0.3927 - val_loss: 1.9289 - val_acc: 0.3650
#
# Epoch 00004: val_acc improved from 0.31375 to 0.36500, saving model to ./models/crnn/weights.best.h5
# Epoch 5/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.8048 - acc: 0.4151 - val_loss: 2.2496 - val_acc: 0.2475
#
# Epoch 00005: val_acc did not improve from 0.36500
# Epoch 6/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.7813 - acc: 0.4196 - val_loss: 2.1302 - val_acc: 0.2963
#
# Epoch 00006: val_acc did not improve from 0.36500
# Epoch 7/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.7528 - acc: 0.4318 - val_loss: 2.1530 - val_acc: 0.2675
#
# Epoch 00007: val_acc did not improve from 0.36500
# Epoch 8/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.7244 - acc: 0.4378 - val_loss: 1.8533 - val_acc: 0.3650
#
# Epoch 00008: val_acc did not improve from 0.36500
# Epoch 9/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.7032 - acc: 0.4478 - val_loss: 1.9281 - val_acc: 0.3125
#
# Epoch 00009: val_acc did not improve from 0.36500
# Epoch 10/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.6898 - acc: 0.4492 - val_loss: 1.8805 - val_acc: 0.3588
#
# Epoch 00010: val_acc did not improve from 0.36500
# Epoch 11/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.6791 - acc: 0.4512 - val_loss: 1.7888 - val_acc: 0.3563
#
# Epoch 00011: val_acc did not improve from 0.36500
# Epoch 12/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.6428 - acc: 0.4639 - val_loss: 2.1441 - val_acc: 0.2938
#
# Epoch 00012: val_acc did not improve from 0.36500
# Epoch 13/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.6453 - acc: 0.4667 - val_loss: 1.9037 - val_acc: 0.3450
#
# Epoch 00013: val_acc did not improve from 0.36500
# Epoch 14/70
# 6394/6394 [==============================] - 27s 4ms/step - loss: 1.6180 - acc: 0.4770 - val_loss: 2.0331 - val_acc: 0.2925
#
# Epoch 00014: val_acc did not improve from 0.36500
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/70
# 6394/6394 [==============================] - 27s 4ms/step - loss: 1.5583 - acc: 0.5038 - val_loss: 1.9971 - val_acc: 0.3075
#
# Epoch 00015: val_acc did not improve from 0.36500
# Epoch 16/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.5258 - acc: 0.5080 - val_loss: 1.8765 - val_acc: 0.3712
#
# Epoch 00016: val_acc improved from 0.36500 to 0.37125, saving model to ./models/crnn/weights.best.h5
# Epoch 17/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4961 - acc: 0.5258 - val_loss: 2.9433 - val_acc: 0.2188
#
# Epoch 00017: val_acc did not improve from 0.37125
# Epoch 18/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.5021 - acc: 0.5205 - val_loss: 1.8461 - val_acc: 0.3937
#
# Epoch 00018: val_acc improved from 0.37125 to 0.39375, saving model to ./models/crnn/weights.best.h5
# Epoch 19/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4681 - acc: 0.5355 - val_loss: 1.9702 - val_acc: 0.3450
#
# Epoch 00019: val_acc did not improve from 0.39375
# Epoch 20/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4499 - acc: 0.5405 - val_loss: 2.0422 - val_acc: 0.3063
#
# Epoch 00020: val_acc did not improve from 0.39375
# Epoch 21/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4489 - acc: 0.5441 - val_loss: 1.7961 - val_acc: 0.3825
#
# Epoch 00021: val_acc did not improve from 0.39375
# Epoch 22/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4305 - acc: 0.5544 - val_loss: 1.7779 - val_acc: 0.3900
#
# Epoch 00022: val_acc did not improve from 0.39375
# Epoch 23/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4234 - acc: 0.5500 - val_loss: 1.7626 - val_acc: 0.4075
#
# Epoch 00023: val_acc improved from 0.39375 to 0.40750, saving model to ./models/crnn/weights.best.h5
# Epoch 24/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.4130 - acc: 0.5485 - val_loss: 1.8698 - val_acc: 0.3613
#
# Epoch 00024: val_acc did not improve from 0.40750
# Epoch 25/70
# 6394/6394 [==============================] - 27s 4ms/step - loss: 1.3947 - acc: 0.5637 - val_loss: 2.0668 - val_acc: 0.3362
#
# Epoch 00025: val_acc did not improve from 0.40750
# Epoch 26/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.3795 - acc: 0.5660 - val_loss: 1.7722 - val_acc: 0.4000
#
# Epoch 00026: val_acc did not improve from 0.40750
# Epoch 27/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3658 - acc: 0.5627 - val_loss: 1.7291 - val_acc: 0.4175
#
# Epoch 00027: val_acc improved from 0.40750 to 0.41750, saving model to ./models/crnn/weights.best.h5
# Epoch 28/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3697 - acc: 0.5673 - val_loss: 2.2350 - val_acc: 0.2863
#
# Epoch 00028: val_acc did not improve from 0.41750
# Epoch 29/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3600 - acc: 0.5737 - val_loss: 1.8353 - val_acc: 0.3625
#
# Epoch 00029: val_acc did not improve from 0.41750
# Epoch 30/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3430 - acc: 0.5790 - val_loss: 1.7938 - val_acc: 0.3987
#
# Epoch 00030: val_acc did not improve from 0.41750
# Epoch 31/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3429 - acc: 0.5870 - val_loss: 2.1605 - val_acc: 0.2988
#
# Epoch 00031: val_acc did not improve from 0.41750
# Epoch 32/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3337 - acc: 0.5929 - val_loss: 2.0677 - val_acc: 0.3337
#
# Epoch 00032: val_acc did not improve from 0.41750
# Epoch 33/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.3162 - acc: 0.5848 - val_loss: 2.0359 - val_acc: 0.3513
#
# Epoch 00033: val_acc did not improve from 0.41750
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 34/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.2856 - acc: 0.5984 - val_loss: 1.7174 - val_acc: 0.4488
#
# Epoch 00034: val_acc improved from 0.41750 to 0.44875, saving model to ./models/crnn/weights.best.h5
# Epoch 35/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.2540 - acc: 0.6053 - val_loss: 1.6365 - val_acc: 0.4537
#
# Epoch 00035: val_acc improved from 0.44875 to 0.45375, saving model to ./models/crnn/weights.best.h5
# Epoch 36/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.2552 - acc: 0.6129 - val_loss: 1.9770 - val_acc: 0.4138
#
# Epoch 00036: val_acc did not improve from 0.45375
# Epoch 37/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.2286 - acc: 0.6207 - val_loss: 1.7588 - val_acc: 0.4262
#
# Epoch 00037: val_acc did not improve from 0.45375
# Epoch 38/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.2397 - acc: 0.6148 - val_loss: 1.6573 - val_acc: 0.4450
#
# Epoch 00038: val_acc did not improve from 0.45375
# Epoch 39/70
# 6394/6394 [==============================] - 28s 4ms/step - loss: 1.2180 - acc: 0.6203 - val_loss: 1.7272 - val_acc: 0.4437
#
# Epoch 00039: val_acc did not improve from 0.45375
# Epoch 40/70
# 6394/6394 [==============================] - 28s 4ms/step - loss: 1.2122 - acc: 0.6225 - val_loss: 1.6658 - val_acc: 0.4612
#
# Epoch 00040: val_acc improved from 0.45375 to 0.46125, saving model to ./models/crnn/weights.best.h5
# Epoch 41/70
# 6394/6394 [==============================] - 29s 5ms/step - loss: 1.1975 - acc: 0.6298 - val_loss: 1.8288 - val_acc: 0.3837
#
# Epoch 00041: val_acc did not improve from 0.46125
# Epoch 42/70
# 6394/6394 [==============================] - 28s 4ms/step - loss: 1.1989 - acc: 0.6278 - val_loss: 1.7290 - val_acc: 0.4475
#
# Epoch 00042: val_acc did not improve from 0.46125
# Epoch 43/70
# 6394/6394 [==============================] - 28s 4ms/step - loss: 1.1985 - acc: 0.6304 - val_loss: 3.7053 - val_acc: 0.2275
#
# Epoch 00043: val_acc did not improve from 0.46125
# Epoch 44/70
# 6394/6394 [==============================] - 30s 5ms/step - loss: 1.1762 - acc: 0.6392 - val_loss: 1.9096 - val_acc: 0.4250
#
# Epoch 00044: val_acc did not improve from 0.46125
# Epoch 45/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1787 - acc: 0.6384 - val_loss: 1.7541 - val_acc: 0.4363
#
# Epoch 00045: val_acc did not improve from 0.46125
# Epoch 46/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1932 - acc: 0.6331 - val_loss: 1.8999 - val_acc: 0.4375
#
# Epoch 00046: val_acc did not improve from 0.46125
# Epoch 47/70
# 6394/6394 [==============================] - 27s 4ms/step - loss: 1.1700 - acc: 0.6400 - val_loss: 1.8569 - val_acc: 0.4150
#
# Epoch 00047: val_acc did not improve from 0.46125
# Epoch 48/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1646 - acc: 0.6331 - val_loss: 1.6832 - val_acc: 0.4725
#
# Epoch 00048: val_acc improved from 0.46125 to 0.47250, saving model to ./models/crnn/weights.best.h5
# Epoch 49/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1625 - acc: 0.6439 - val_loss: 2.0296 - val_acc: 0.3837
#
# Epoch 00049: val_acc did not improve from 0.47250
# Epoch 50/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1577 - acc: 0.6381 - val_loss: 1.8364 - val_acc: 0.4488
#
# Epoch 00050: val_acc did not improve from 0.47250
# Epoch 51/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1519 - acc: 0.6451 - val_loss: 1.7973 - val_acc: 0.4150
#
# Epoch 00051: val_acc did not improve from 0.47250
# Epoch 52/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1576 - acc: 0.6408 - val_loss: 1.9445 - val_acc: 0.3775
#
# Epoch 00052: val_acc did not improve from 0.47250
# Epoch 53/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1442 - acc: 0.6492 - val_loss: 1.9388 - val_acc: 0.3775
#
# Epoch 00053: val_acc did not improve from 0.47250
# Epoch 54/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1338 - acc: 0.6536 - val_loss: 2.1573 - val_acc: 0.3725
#
# Epoch 00054: val_acc did not improve from 0.47250
# Epoch 55/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1442 - acc: 0.6454 - val_loss: 1.8157 - val_acc: 0.4763
#
# Epoch 00055: val_acc improved from 0.47250 to 0.47625, saving model to ./models/crnn/weights.best.h5
# Epoch 56/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1349 - acc: 0.6567 - val_loss: 1.8770 - val_acc: 0.4025
#
# Epoch 00056: val_acc did not improve from 0.47625
# Epoch 57/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.1300 - acc: 0.6550 - val_loss: 1.9213 - val_acc: 0.4512
#
# Epoch 00057: val_acc did not improve from 0.47625
# Epoch 58/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.1172 - acc: 0.6594 - val_loss: 2.5100 - val_acc: 0.3700
#
# Epoch 00058: val_acc did not improve from 0.47625
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 59/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0761 - acc: 0.6662 - val_loss: 1.7660 - val_acc: 0.4675
#
# Epoch 00059: val_acc did not improve from 0.47625
# Epoch 60/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0693 - acc: 0.6774 - val_loss: 2.0361 - val_acc: 0.4612
#
# Epoch 00060: val_acc did not improve from 0.47625
# Epoch 61/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.0774 - acc: 0.6669 - val_loss: 1.7809 - val_acc: 0.4550
#
# Epoch 00061: val_acc did not improve from 0.47625
# Epoch 62/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.0742 - acc: 0.6722 - val_loss: 1.8024 - val_acc: 0.4612
#
# Epoch 00062: val_acc did not improve from 0.47625
# Epoch 63/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0639 - acc: 0.6784 - val_loss: 1.9765 - val_acc: 0.4213
#
# Epoch 00063: val_acc did not improve from 0.47625
# Epoch 64/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.0470 - acc: 0.6786 - val_loss: 1.7011 - val_acc: 0.4800
#
# Epoch 00064: val_acc improved from 0.47625 to 0.48000, saving model to ./models/crnn/weights.best.h5
# Epoch 65/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.0390 - acc: 0.6836 - val_loss: 1.8137 - val_acc: 0.4350
#
# Epoch 00065: val_acc did not improve from 0.48000
# Epoch 66/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0363 - acc: 0.6842 - val_loss: 1.7310 - val_acc: 0.4575
#
# Epoch 00066: val_acc did not improve from 0.48000
# Epoch 67/70
# 6394/6394 [==============================] - 26s 4ms/step - loss: 1.0193 - acc: 0.6947 - val_loss: 1.7489 - val_acc: 0.4750
#
# Epoch 00067: val_acc did not improve from 0.48000
# Epoch 68/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0469 - acc: 0.6813 - val_loss: 1.6777 - val_acc: 0.4825
#
# Epoch 00068: val_acc improved from 0.48000 to 0.48250, saving model to ./models/crnn/weights.best.h5
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 69/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0169 - acc: 0.6964 - val_loss: 1.7268 - val_acc: 0.4612
#
# Epoch 00069: val_acc did not improve from 0.48250
# Epoch 70/70
# 6394/6394 [==============================] - 25s 4ms/step - loss: 1.0135 - acc: 0.6988 - val_loss: 1.7890 - val_acc: 0.4612
#
# Epoch 00070: val_acc did not improve from 0.48250

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.34      0.67      0.45       100
#  Experimental       0.41      0.54      0.46       100
#          Folk       0.76      0.54      0.63       100
#       Hip-Hop       0.60      0.41      0.49       100
#  Instrumental       0.37      0.35      0.36       100
# International       0.63      0.54      0.58       100
#           Pop       0.12      0.08      0.10       100
#          Rock       0.67      0.56      0.61       100
#
#      accuracy                           0.46       800
#     macro avg       0.49      0.46      0.46       800
#  weighted avg       0.49      0.46      0.46       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.46125

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.52      0.26      0.35       100
#  Experimental       0.26      0.29      0.27       100
#          Folk       0.10      0.10      0.10       100
#       Hip-Hop       0.72      0.77      0.74       100
#  Instrumental       0.38      0.22      0.28       100
# International       0.47      0.54      0.50       100
#           Pop       0.29      0.49      0.37       100
#          Rock       0.54      0.51      0.53       100
#
#      accuracy                           0.40       800
#     macro avg       0.41      0.40      0.39       800
#  weighted avg       0.41      0.40      0.39       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 800/800 [==============================] - 1s 2ms/step
# [1.9597721099853516, 0.3975]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred, normalize='true'))
# Out:
# [[0.26 0.04 0.09 0.12 0.02 0.17 0.25 0.05]
#  [0.05 0.29 0.14 0.03 0.1  0.13 0.14 0.12]
#  [0.   0.38 0.1  0.   0.18 0.09 0.2  0.05]
#  [0.05 0.01 0.   0.77 0.01 0.05 0.09 0.02]
#  [0.05 0.27 0.3  0.01 0.22 0.06 0.07 0.02]
#  [0.03 0.   0.19 0.04 0.01 0.54 0.15 0.04]
#  [0.05 0.02 0.11 0.1  0.01 0.09 0.49 0.13]
#  [0.01 0.12 0.04 0.   0.03 0.01 0.28 0.51]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.3975

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize = (8,7), dpi = 400)
plt.tight_layout()
sns.set(font_scale=1.4) # for label size
mat = confusion_matrix(y_true, y_pred, normalize='true')
sns.heatmap(mat.T, square=True, annot=True, annot_kws={"size": 16}, fmt='.2f', cbar=True,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
plt.savefig('crnn_confusion_matrix.png', bbox_inches = 'tight')
